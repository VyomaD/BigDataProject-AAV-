# %% [markdown]
# ### Importing all the Libraries

# %%
# !pip install geotext

# %%
pysparkzip = "/opt/dse/resources/spark/python/lib/pyspark.zip"
py4jzip = "/opt/dse/resources/spark/python/lib/py4j-0.10.4-src.zip"

# %%
# Needed to be able to find pyspark libaries
import sys
sys.path.append(pysparkzip)
sys.path.append(py4jzip)

# %%
import pandas
import cassandra
import pyspark
import tweepy
import re
import os
from IPython.display import display, Markdown
from pyspark.sql import SparkSession
from pyspark.ml.feature import Tokenizer, RegexTokenizer, StopWordsRemover
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType
from pattern.en import sentiment, positive
from geotext import GeoText
import unicodedata

# %% [markdown]
# ### Importing Twitter API keys and tokens

# %%
consumer_key = os.environ['CONSUMER_KEY']
consumer_secret = os.environ['CONSUMER_SECRET']
access_token = os.environ['ACCESS_TOKEN']
access_token_secret = os.environ['ACCESS_TOKEN_SECRET']


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ### Function to format Spark DataFrames

# %%
def showDF(df, limitRows =  5, truncate = True):
    if(truncate):
        pandas.set_option('display.max_colwidth', 50)
    else:
        pandas.set_option('display.max_colwidth', -1)
    pandas.set_option('display.max_rows', limitRows)
    display(df.limit(limitRows).toPandas())
    pandas.reset_option('display.max_rows')

# %% [markdown]
# ### Creating Tables, Pulling Tweets, and Loading Tables

# %% [markdown]
# #### Connect to Cluster

# %%
from cassandra.cluster import Cluster

cluster = Cluster(['dse'])
session = cluster.connect()

# %% [markdown]
# #### Keyspace

# %%
session.execute("""
    CREATE KEYSPACE IF NOT EXISTS sentimentanalytics
    WITH REPLICATION = 
    { 'class' : 'SimpleStrategy', 'replication_factor' : 1 }"""
)

# %% [markdown]
# #### Setting keyspace

# %%
session.set_keyspace('sentimentanalytics')

# %%
tweetTitle = "covid19"

# %%
positiveNegative = ["positive", "negative"]

# %%
query = "DROP TABLE sentiment_%s_%s" % (tweetTitle, positiveNegative[0])
session.execute(query)
query = "DROP TABLE sentiment_%s_%s" % (tweetTitle, positiveNegative[1])
session.execute(query)



for emotion in positiveNegative:
    query = "CREATE TABLE IF NOT EXISTS sentiment_%s_%s (twitterid bigint, tweet text, city text, country text,\
    user text, createdat text, hashtagkeys text, source text, retweets int, userstatuscount int, PRIMARY KEY \
    ((twitterid, tweet, city, country, user, hashtagkeys, source, retweets, userstatuscount), createdat)) with \
    clustering order by (createdat desc)" % (tweetTitle, emotion)
    print query
    session.execute(query)
# Out:
# CREATE TABLE IF NOT EXISTS sentiment_covid19_positive (twitterid bigint, tweet text, city text, country text,    user text, createdat text, hashtagkeys text, source text, retweets int, userstatuscount int, PRIMARY KEY     ((twitterid, tweet, city, country, user, hashtagkeys, source, retweets, userstatuscount), createdat)) with     clustering order by (createdat desc)
# CREATE TABLE IF NOT EXISTS sentiment_covid19_negative (twitterid bigint, tweet text, city text, country text,    user text, createdat text, hashtagkeys text, source text, retweets int, userstatuscount int, PRIMARY KEY     ((twitterid, tweet, city, country, user, hashtagkeys, source, retweets, userstatuscount), createdat)) with     clustering order by (createdat desc)

# %%
# for emotion in positiveNegative:
# #     query = "CREATE TABLE IF NOT EXISTS covid_sentiments1_%s_%s (twitterid bigint, tweet text, place text, user text,\
# #              createdat timestamp, hashtagkeys text, source text, retweets text, userstatuscount text,userscreenname \
# #              text, PRIMARY KEY (twitterid))" % (tweetTitle, emotion)
#     query = "CREATE TABLE IF NOT EXISTS sentimentofCountry_%s_%s (twitterid bigint, country text, tweet text, city text, \
#     user text, createdat text, hashtagkeys text, source text, retweets int, userstatuscount int, PRIMARY KEY \
#     ((country), createdat)) with \
#     clustering order by (createdat desc)" % (tweetTitle, emotion)
#     print query
#     session.execute(query)

# %%
'''Function to CleanUp Each Tweet before if is inserted into Cassandra.
    Removing: 
        * emojis 
        * flags 
        * special characters 
        * URL's 
        * RT (for Retweet)
'''

def cleanUpTweet(tweet):
    if tweet == None:
        return 'unknown'
    
    emoji_pattern = re.compile(
    u"(\ud83d[\ude00-\ude4f])|"
    u"(\ud83c[\udf00-\uffff])|"  
    u"(\ud83d[\u0000-\uddff])|" 
    u"(\ud83d[\ude80-\udeff])|"  
    u"(\ud83c[\udde0-\uddff])" 
    "+", flags=re.UNICODE)

#     removeSpecial = re.compile ('[\n|#|@|!|.|?|,|\"]')
    removeSpecial = re.compile ('[\n|@|!|.|?|,|\"]')
    removeHttp = re.compile("http\S+ | https\S+")
    removeRetweet = re.compile("RT")
    
    noemoji = emoji_pattern.sub(r'', tweet)
    nospecial = removeSpecial.sub(r'', noemoji)
    nohttp = removeHttp.sub(r'', nospecial)
    noretweet = removeRetweet.sub(r'', nohttp)
    
    cleanTweet=noretweet
#     cleanTweet = ''.join([x for x in cleanTweet if x.isalnum()])
#     cleanTweet = re.sub(r"[^a-zA-Z0-9:.,@#&]+", ' ', cleanTweet)
    cleanTweet = unicodedata.normalize('NFKD', cleanTweet).encode('ascii', 'ignore')
    return cleanTweet


def cleanUpPlace(tweet):
    if tweet == None:
        return 'unknown'
    tweet = tweet.title()
    places = GeoText(tweet)
    cities = list(places.cities)
    countries = list(places.countries)
    city, country = 'unknown', 'unknown'
    if len(cities) > 0:
        city = str(cities[0])
    if len(countries) > 0:
        country = str(countries[0])
    return (city, country)

def cleanHashtags(hashtag_dict):
    hashtags = []
    for h_dict in hashtag_dict:
        for h in h_dict.values():
            if type(h) == unicode:
                decoded = unicodedata.normalize('NFKD', h).encode('ascii', 'ignore')
                hashtags.append(decoded)
    
    if len(hashtags) == 0:
        hashtags = ['unknown']
    
    hashtags = ','.join(hashtags)
    return hashtags

# %%
# pulling data from twitter and inserting into cassandra
titles = ['Covid19']#, 'Covid-19', 'Coronavirus', 'StayHomeStaySafe', 'StayHome', 'LockdownNow']
pos_tags = [' recovery', ' vaccinated']#, ' relax', ' strong', ' cheers', ' blessed', ' care', 
                                       #' QuarantineandChill', ' SocialDistancing']
neg_tags = [' deaths', ' frustrated']#, ' terrible', ' unfocussed', ' fear', ' no vaccine', ' stress', 
                                     #' anxiety', ' worry', ' hardship', ' Covidiots']

pos_terms = [x+y for x in titles for y in pos_tags]
neg_terms = [x+y for x in titles for y in neg_tags]

searchTerms = [pos_terms, neg_terms]


for emotion in positiveNegative:
    print emotion
    public_tweets = 0
    query = "INSERT INTO sentiment_%s_%s (twitterid, tweet, city, country, user, createdat, hashtagkeys, source, retweets, userstatuscount)" % (tweetTitle, emotion)
    query = query + " VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    
    public_tweets_list = []
    for i in range(10):
        if emotion == "positive":
            for searchTerm in searchTerms[0]:
                public_tweets = api.search(q=searchTerm, lang="en", count="100")
                public_tweets_list.append(public_tweets)
        if emotion == "negative":
            for searchTerm in searchTerms[1]:
                public_tweets = api.search(q=searchTerm, lang="en", count="100")
                public_tweets_list.append(public_tweets)
    
    for public_tweets in public_tweets_list:
        for tweet in public_tweets:
            cleanTweet = cleanUpTweet(tweet.text)
            city, country = cleanUpPlace(tweet.user.location)
            username = cleanUpTweet(tweet.user.name)
            createdat = str(tweet.created_at.date())
            hashtags = tweet.entities['hashtags']
            hashtags = cleanHashtags(hashtags)
            source = tweet.source
            retweets = tweet.retweet_count
            userstatus = tweet.user.statuses_count
            
            session.execute(query, (tweet.id, cleanTweet.encode('utf-8'), city, country, username, createdat, hashtags, source, retweets, userstatus))
# Out:
# positive
# negative

# %%
# Query 1
for emotion in positiveNegative:
    print("\n... Checking the conents of {} table".format(emotion))
    query = 'SELECT * FROM sentiment_%s_%s limit 2' % (tweetTitle, emotion)
    rows = session.execute(query)
    for user_row in rows:
        print(user_row)
# Out:
# ... Checking the conents of positive table
# Row(twitterid=1390766965292101633, tweet=u" dw_europe: EU leaders are meeting in Portugal to discuss the bloc's social affairs strategy against the backdrop of the #COVID19 pandem...", city=u'unknown', country=u'unknown', user=u'JM Hamilton', hashtagkeys=u'COVID19', source=u'Twitter Web App', retweets=9, userstatuscount=621164, createdat=u'2021-05-07')
# Row(twitterid=1390759589310865415, tweet=u" DrAmbrishMithal: Don't chase #PCest after recoveryRepeat #PCR NOT necessary&gt;10 days after onset of symptoms&gt;3 days after absen...", city=u'Noida', country=u'India', user=u'Nikhil katiyar', hashtagkeys=u'RTPCRTest,RTPCR', source=u'Twitter for iPhone', retweets=127, userstatuscount=494, createdat=u'2021-05-07')
#
# ... Checking the conents of negative table
# Row(twitterid=1390610581359562756, tweet=u' foogatwo: #NJ #COVID19 Case update for 5/5 Mass Deletions continuing Groundhog day Growing increasingly frustrated with inability of...', city=u'unknown', country=u'unknown', user=u'Sunny moonshine', hashtagkeys=u'NJ,COVID19', source=u'Twitter Web App', retweets=76, userstatuscount=885, createdat=u'2021-05-07')
# Row(twitterid=1390776623432179715, tweet=u' DrEricDing: HUGE EXCESS DEATHSglobal #COVID19 death toll is 2x higher than official data69 mil worldwide Deaths:US 905kIndi...', city=u'unknown', country=u'unknown', user=u'Pablo Miguel', hashtagkeys=u'COVID19', source=u'Twitter Web App', retweets=1394, userstatuscount=1364, createdat=u'2021-05-07')

# %%
# Query 2: Find out the maximum number of times a particular hashtag has been used and the user 
# which has maximum retweets with that keyword in both the positive and negative table
for emotion in positiveNegative:
    print emotion
    query = "SELECT max(retweets), max(user) FROM sentiment_%s_%s where hashtagkeys='COVID19' ALLOW FILTERING" % (tweetTitle, emotion)
    rows = session.execute(query)
    for user_row in rows:
        print(user_row)
# Out:
# positive
# Row(system_max_retweets=1132, system_max_user=u'sic')
# negative
# Row(system_max_retweets=1394, system_max_user=u'stay blazin')

# %%
# Query 3: Finding distinct values based on country
for emotion in positiveNegative:
    print '\n',emotion
    query = "SELECT DISTINCT twitterid, tweet, city, country, user, hashtagkeys, source, retweets, userstatuscount \
    FROM sentiment_%s_%s where country='India' LIMIT 2 ALLOW FILTERING" % (tweetTitle, emotion)
    rows = session.execute(query)
    for user_row in rows:
        print(user_row)
# Out:
# positive
# Row(twitterid=1390759589310865415, tweet=u" DrAmbrishMithal: Don't chase #PCest after recoveryRepeat #PCR NOT necessary&gt;10 days after onset of symptoms&gt;3 days after absen...", city=u'Noida', country=u'India', user=u'Nikhil katiyar', hashtagkeys=u'RTPCRTest,RTPCR', source=u'Twitter for iPhone', retweets=127, userstatuscount=494)
# Row(twitterid=1390777601547931648, tweet=u' sanjuydv: Shamefully Bihar stands at 8th rank in wastage of life saving Covid19 vaccines in IndiaMerely 766 lakh out of 13 Cr hv be...', city=u'Katihar', country=u'India', user=u'Suraj kumar', hashtagkeys=u'unknown', source=u'Twitter for Android', retweets=854, userstatuscount=533)
#
# negative
# Row(twitterid=1390688541802258436, tweet=u'shalmida drakchaurasia Sir He is in depressionFrustrated guyIgnore himMay God bless him with Covid19 and...', city=u'Ahmedabad', country=u'India', user=u'KUNDALINIYOGA #BabubhaiThakkar', hashtagkeys=u'unknown', source=u'Twitter for Android', retweets=0, userstatuscount=3110)
# Row(twitterid=1390607576828624898, tweet=u'Young Thais take to social media to vent against their government while stressing in post after post that they were...', city=u'unknown', country=u'India', user=u'UCAN India', hashtagkeys=u'unknown', source=u'SocialPilot.co', retweets=0, userstatuscount=19576)

# %%
# Query 4: Finding number of people tweeting positive and negative stuff from two different countries
for emotion in positiveNegative:
    print emotion
    query = "SELECT count(country) as Indians FROM sentiment_%s_%s where country='India' ALLOW FILTERING" % (tweetTitle, emotion)
    rows = session.execute(query)
    for user_row in rows:
        print(user_row)
        
    query = "SELECT count(country) as Canadians FROM sentiment_%s_%s where country='Canada' ALLOW FILTERING" % (tweetTitle, emotion)
    rows = session.execute(query)
    for user_row in rows:
        print(user_row)
# Out:
# positive
# Row(indians=13)
# Row(canadians=8)
# negative
# Row(indians=3)
# Row(canadians=3)

# %%
# Query 5: Finding the number of tweets from a particular platform
for emotion in positiveNegative:
    print emotion
    query = "SELECT count(*) FROM sentiment_%s_%s where source='Twitter Web App' ALLOW FILTERING" % (tweetTitle, emotion)
    rows = session.execute(query)
#     print(rows)
    for user_row in rows:
        print(user_row)
# Out:
# positive
# Row(count=65)
# negative
# Row(count=53)

# %%
# Query 6: Finding number of tweets with retweets > 25
for emotion in positiveNegative:
    print emotion
    query = "SELECT count(*) FROM sentiment_%s_%s where retweets>25 ALLOW FILTERING" % (tweetTitle, emotion)
    rows = session.execute(query)
#     print(rows)
    for user_row in rows:
        print(user_row)
# Out:
# positive
# Row(count=80)
# negative
# Row(count=124)

# %%
# # Which countries are most people twitting from?
# for emotion in positiveNegative:
#     print emotion
#     query = "SELECT country, hashtagkeys FROM sentiment_%s_%s group by country ALLOW FILTERING" % (tweetTitle, emotion)
#     rows = session.execute(query)
# #     print(rows)
#     for user_row in rows:
#         print(user_row)

# %% [markdown]
# #### Creating a spark session which is connected to Cassandra and counting the number of rows in each.

# %%
countTokens = udf(lambda words: len(words), IntegerType())

# spark = SparkSession.builder.appName('demo').master("local").getOrCreate()
spark = SparkSession.builder.appName('demo').master("dse://dse:9042").getOrCreate()

tableNamePos = "sentiment_%s_positive" % (tweetTitle.lower())
tableNameNeg = "sentiment_%s_negative" % (tweetTitle.lower())

tablepos = spark.read.format("org.apache.spark.sql.cassandra").options(table=tableNamePos, keyspace="sentimentanalytics").load()
tableneg = spark.read.format("org.apache.spark.sql.cassandra").options(table=tableNameNeg, keyspace="sentimentanalytics").load()

print "Postive Table Count: "
print tablepos.count()
print "Negative Table Count: "
print tableneg.count()
print(tablepos)
display(tablepos)
# Out:
# Postive Table Count:
# 220
# Negative Table Count:
# 209
# DataFrame[twitterid: bigint, tweet: string, city: string, country: string, user: string, hashtagkeys: string, source: string, retweets: int, userstatuscount: int, createdat: string]
# DataFrame[twitterid: bigint, tweet: string, city: string, country: string, user: string, hashtagkeys: string, source: string, retweets: int, userstatuscount: int, createdat: string]

# %%
# import pandas as pd
# df = tablepos.toPandas()
# df.to_csv('/project_folder/allTweetScores_s.csv', index=False)
# tablepos.write.format("csv").save('/project_folder/allTweetScores_s.csv')

# %% [markdown]
# #### Sentence to words tokenizer

# %%
tokenizerPos = Tokenizer(inputCol="tweet", outputCol="tweetwords")
tokenizedPos = tokenizerPos.transform(tablepos)
dfPos = tokenizedPos.select("tweetwords", "city", "country", "createdat", "hashtagkeys", "source", "retweets", "userstatuscount").withColumn("tokens", countTokens(col("tweetwords")))
showDF(dfPos)

tokenizerNeg = Tokenizer(inputCol="tweet", outputCol="tweetwords")
tokenizedNeg = tokenizerNeg.transform(tableneg)
dfNeg = tokenizedNeg.select("tweetwords", "city", "country", "createdat", "hashtagkeys","source", "retweets", "userstatuscount").withColumn("tokens", countTokens(col("tweetwords")))
showDF(dfNeg)

print(dfPos.count())
print(dfNeg.count())
# Out:
#                                           tweetwords       city  country  \
# 0  [, binancebcf:, #binance, charity's, year-long...    unknown  unknown
# 1  [, cdcgov:, at, the, start, of, 2021, people, ...    unknown  unknown
# 2  [, wef:, two, key, conditions, for, a, post-pa...    unknown  unknown
# 3  [#corona, info, for, #usa:new, cases:, 27163to...  Karlsruhe  Germany
# 4  [, ethicalsid:, one, can, feel, in, saurabh_ml...      Dubai  unknown
#
#     createdat        hashtagkeys              source  retweets  \
# 0  2021-05-07            Binance  Twitter for iPhone         4
# 1  2021-05-07            COVID19     Twitter Web App        37
# 2  2021-05-07  covid19,economics    Twitter for iPad        12
# 3  2021-05-07         Corona,USA  corona-tracker-app         0
# 4  2021-05-07            COVID19  Twitter for iPhone       151
#
#    userstatuscount  tokens
# 0              617      18
# 1           186560      24
# 2            15526      13
# 3            13927      14
# 4             2770      23
#                                           tweetwords     city  country  \
# 0  [05/07/2021, update:people, tested:, 905825, (...  unknown  unknown
# 1  [, jkwan_md:, may, 7:, #covid19, in, #ontario3...  unknown   Canada
# 2  [robking65, natwittee, ctvnews, none, it's, a,...  Toronto   Canada
# 3  [#alberta, restaurant, owners, frustrated, as,...  unknown  unknown
# 4  [look, what, u, voted, 4, a, man, without, an,...  unknown  unknown
#
#     createdat      hashtagkeys               source  retweets  \
# 0  2021-05-07          unknown          ri_covid_19         0
# 1  2021-05-07  COVID19,Ontario      Twitter Web App       102
# 2  2021-05-07          unknown  Twitter for Android         0
# 3  2021-05-06  Alberta,COVID19   Twitter for iPhone         0
# 4  2021-05-07          unknown  Twitter for Android         2
#
#    userstatuscount  tokens
# 0              315      11
# 1           348030      15
# 2             1540      17
# 3            43243      14
# 4           232906      21
# 220
# 209

# %% [markdown]
# #### Removing stop words

# %%
removerPos = StopWordsRemover(inputCol="tweetwords", outputCol="tweetnostopwords")
removedPos = removerPos.transform(dfPos)
dfPosStop = removedPos.select("tweetwords", "tweetnostopwords", "city", "country", "createdat", "hashtagkeys","source", "retweets", "userstatuscount").withColumn("tokens", countTokens(col("tweetwords"))).withColumn("notokens", countTokens(col("tweetnostopwords")))
showDF(dfPosStop)

removerNeg = StopWordsRemover(inputCol="tweetwords", outputCol="tweetnostopwords")
removedNeg = removerNeg.transform(dfNeg)
dfNegStop = removedNeg.select("tweetwords", "tweetnostopwords", "city", "country", "createdat", "hashtagkeys","source", "retweets", "userstatuscount").withColumn("tokens", countTokens(col("tweetwords"))).withColumn("notokens", countTokens(col("tweetnostopwords")))
showDF(dfNegStop)

print(dfPosStop.count())
print(dfNegStop.count())
# Out:
#                                           tweetwords  \
# 0  [, binancebcf:, #binance, charity's, year-long...
# 1  [, cdcgov:, at, the, start, of, 2021, people, ...
# 2  [, wef:, two, key, conditions, for, a, post-pa...
# 3  [#corona, info, for, #usa:new, cases:, 27163to...
# 4  [, ethicalsid:, one, can, feel, in, saurabh_ml...
#
#                                     tweetnostopwords       city  country  \
# 0  [, binancebcf:, #binance, charity's, year-long...    unknown  unknown
# 1  [, cdcgov:, start, 2021, people, 65+, half, #c...    unknown  unknown
# 2  [, wef:, two, key, conditions, post-pandemic, ...    unknown  unknown
# 3  [#corona, info, #usa:new, cases:, 27163today, ...  Karlsruhe  Germany
# 4  [, ethicalsid:, one, feel, saurabh_mlagk's, vo...      Dubai  unknown
#
#     createdat        hashtagkeys              source  retweets  \
# 0  2021-05-07            Binance  Twitter for iPhone         4
# 1  2021-05-07            COVID19     Twitter Web App        37
# 2  2021-05-07  covid19,economics    Twitter for iPad        12
# 3  2021-05-07         Corona,USA  corona-tracker-app         0
# 4  2021-05-07            COVID19  Twitter for iPhone       151
#
#    userstatuscount  tokens  notokens
# 0              617      18        15
# 1           186560      24        12
# 2            15526      13        11
# 3            13927      14        13
# 4             2770      23        14
#                                           tweetwords  \
# 0  [05/07/2021, update:people, tested:, 905825, (...
# 1  [, jkwan_md:, may, 7:, #covid19, in, #ontario3...
# 2  [robking65, natwittee, ctvnews, none, it's, a,...
# 3  [#alberta, restaurant, owners, frustrated, as,...
# 4  [look, what, u, voted, 4, a, man, without, an,...
#
#                                     tweetnostopwords     city  country  \
# 0  [05/07/2021, update:people, tested:, 905825, (...  unknown  unknown
# 1  [, jkwan_md:, may, 7:, #covid19, #ontario3166,...  unknown   Canada
# 2  [robking65, natwittee, ctvnews, none, fair, qu...  Toronto   Canada
# 3  [#alberta, restaurant, owners, frustrated, #co...  unknown  unknown
# 4  [look, u, voted, 4, man, without, ounce, consc...  unknown  unknown
#
#     createdat      hashtagkeys               source  retweets  \
# 0  2021-05-07          unknown          ri_covid_19         0
# 1  2021-05-07  COVID19,Ontario      Twitter Web App       102
# 2  2021-05-07          unknown  Twitter for Android         0
# 3  2021-05-06  Alberta,COVID19   Twitter for iPhone         0
# 4  2021-05-07          unknown  Twitter for Android         2
#
#    userstatuscount  tokens  notokens
# 0              315      11        11
# 1           348030      15        14
# 2             1540      17        14
# 3            43243      14        11
# 4           232906      21        14
# 220
# 209

# %% [markdown]
# ### Finding the positive, negative and neutral tweets

# %% [markdown]
# #### Negative Tweets

# %%
pandaNeg = dfNegStop.toPandas()
sentimentScoreNeg = 0
countNeg = 0
numTweets = 0
negList = list()
netralList = list()

for index, row in pandaNeg.iterrows():
    if positive(row["tweetnostopwords"], .1):
        countNeg = countNeg + 1
    scoreNeg = sentiment(row['tweetnostopwords'])[0]
    if scoreNeg <= 0:
        negList.append((row['country'], row['city'], row['createdat'], row['hashtagkeys'], sentiment(row["tweetnostopwords"]), positive(row["tweetnostopwords"]), \
                        sentiment(row['tweetnostopwords']).assessments, row['source'], row['retweets'], row['userstatuscount'], scoreNeg))
        sentimentScoreNeg = scoreNeg + sentimentScoreNeg
    else:
        netralList.append((row['country'], row['city'], row['createdat'], row['hashtagkeys'], sentiment(row["tweetnostopwords"]), positive(row["tweetnostopwords"]), \
                           sentiment(row['tweetnostopwords']).assessments, row['source'], row['retweets'], row['userstatuscount'], scoreNeg))

labels = ['Country', 'City', 'Create_At', 'Hashtags Keyword', 'Sentiment Score', 'Postive', 'Assessments', 'Source', 'Retweets', 'User Status', 'sentiment score']
negativeTweetScores = pandas.DataFrame.from_records(negList, columns=labels)
negativeTweetScores
# Out:
#            Country           City   Create_At  \
# 0          unknown        unknown  2021-05-07
# 1           Canada        unknown  2021-05-07
# 2          unknown        unknown  2021-05-06
# 3          unknown        unknown  2021-05-07
# 4            India        Chennai  2021-05-07
# 5          unknown        unknown  2021-05-07
# 6          unknown        unknown  2021-05-06
# 7          unknown        unknown  2021-05-07
# 8          unknown        unknown  2021-05-06
# 9   United Kingdom        unknown  2021-05-07
# 10         unknown        unknown  2021-05-07
# 11         unknown        unknown  2021-05-07
# 12         unknown        unknown  2021-05-07
# 13          Canada        unknown  2021-05-07
# 14         unknown        unknown  2021-05-07
# 15         unknown        unknown  2021-05-07
# 16         unknown         Boston  2021-05-07
# 17         unknown        unknown  2021-05-07
# 18         unknown        unknown  2021-05-07
# 19         unknown        unknown  2021-05-07
# 20         unknown        unknown  2021-05-07
# 21           Nepal        unknown  2021-05-06
# 22         unknown        unknown  2021-05-07
# 23         unknown        unknown  2021-05-07
# 24         unknown        unknown  2021-05-07
# 25         unknown        unknown  2021-05-07
# 26         unknown        unknown  2021-05-06
# 27         unknown        unknown  2021-05-07
# 28         unknown        unknown  2021-05-07
# 29         unknown        unknown  2021-05-07
# ..             ...            ...         ...
# 46         unknown        unknown  2021-05-07
# 47         unknown        unknown  2021-05-07
# 48         unknown        unknown  2021-05-07
# 49         Germany      Karlsruhe  2021-05-07
# 50         unknown        unknown  2021-05-07
# 51         unknown        unknown  2021-05-07
# 52         unknown        unknown  2021-05-06
# 53         unknown        unknown  2021-05-07
# 54         unknown        unknown  2021-05-07
# 55         unknown        unknown  2021-05-07
# 56         unknown          Ascot  2021-05-07
# 57         unknown        unknown  2021-05-07
# 58         unknown      Kathmandu  2021-05-07
# 59         unknown        unknown  2021-05-07
# 60         unknown        Toronto  2021-05-07
# 61          France          Paris  2021-05-07
# 62         unknown         Boston  2021-05-07
# 63         unknown        unknown  2021-05-07
# 64            Peru           Lima  2021-05-07
# 65         unknown        unknown  2021-05-07
# 66         unknown        unknown  2021-05-07
# 67         unknown        unknown  2021-05-07
# 68         unknown        Toronto  2021-05-07
# 69         unknown  San Francisco  2021-05-07
# 70         unknown        Halifax  2021-05-06
# 71         unknown        unknown  2021-05-06
# 72         unknown          Delhi  2021-05-07
# 73           India      Ahmedabad  2021-05-07
# 74         unknown        unknown  2021-05-07
# 75         unknown        Halifax  2021-05-06
#
#                                      Hashtags Keyword  \
# 0                                             unknown
# 1                                     COVID19,Ontario
# 2                                     Alberta,COVID19
# 3                                             unknown
# 4                                             unknown
# 5                                             COVID19
# 6                                          NJ,COVID19
# 7                                             unknown
# 8                                             unknown
# 9                                             unknown
# 10                                            COVID19
# 11                                            unknown
# 12                                       CovidVaccine
# 13                                    COVID19,Ontario
# 14                                            COVID19
# 15                                            COVID19
# 16                              Massachusetts,Covid19
# 17                                            unknown
# 18                       coronavirus,COVID19,2019ncov
# 19                                            unknown
# 20                                            covid19
# 21                                            unknown
# 22                                            COVID19
# 23  Lockdown,cases,Deaths,Tunisia,tunisie,covid19,...
# 24                                            unknown
# 25                                            unknown
# 26                                    Alberta,COVID19
# 27                                            COVID19
# 28                                            COVID19
# 29                            ToryLies,ToryCorruption
# ..                                                ...
# 46                                            unknown
# 47                                            COVID19
# 48                                            unknown
# 49                                         Corona,USA
# 50                                            COVID19
# 51                                            COVID19
# 52                                    Alberta,COVID19
# 53                                            COVID19
# 54                                            COVID19
# 55                                            unknown
# 56                                            COVID19
# 57                                            COVID19
# 58                                            unknown
# 59                                            COVID19
# 60                                            unknown
# 61                              Massachusetts,Covid19
# 62                                            unknown
# 63                                            COVID19
# 64                          IndiaFightsCorona,COVID19
# 65                                            unknown
# 66                                         NJ,COVID19
# 67                                       Iowa,COVID19
# 68                                            unknown
# 69                                            COVID19
# 70                                         COVID19,NS
# 71                                         NJ,COVID19
# 72                                            unknown
# 73                                            unknown
# 74                                            unknown
# 75                                         COVID19,NS
#
#                       Sentiment Score  Postive  \
# 0                          (0.0, 0.0)    False
# 1                          (0.0, 0.0)    False
# 2                         (-0.7, 0.2)    False
# 3                          (0.0, 0.0)    False
# 4                          (0.0, 0.0)    False
# 5                          (0.0, 0.0)    False
# 6                         (-0.7, 0.2)    False
# 7                          (0.0, 0.0)    False
# 8                          (0.0, 0.0)    False
# 9              (0.0, 0.0666666666667)    False
# 10                         (0.0, 0.0)    False
# 11                         (0.0, 0.0)    False
# 12                         (0.0, 1.0)    False
# 13                         (0.0, 0.0)    False
# 14                         (0.0, 0.0)    False
# 15                         (0.0, 0.0)    False
# 16             (0.0, 0.0666666666667)    False
# 17                        (-0.2, 0.4)    False
# 18                         (0.0, 0.0)    False
# 19                         (0.0, 0.0)    False
# 20                         (0.0, 0.0)    False
# 21                        (-0.6, 0.6)    False
# 22                         (0.0, 0.0)    False
# 23                         (0.0, 0.0)    False
# 24                        (0.0, 0.75)    False
# 25                         (0.0, 0.0)    False
# 26                        (-0.7, 0.2)    False
# 27                         (0.0, 0.0)    False
# 28              (0.0, 0.333333333333)    False
# 29  (-0.107142857143, 0.767857142857)    False
# ..                                ...      ...
# 46                       (0.0, 0.575)    False
# 47              (0.0, 0.333333333333)    False
# 48                         (0.0, 0.0)    False
# 49             (-0.133333333333, 0.6)    False
# 50                         (0.0, 0.0)    False
# 51                         (0.0, 0.0)    False
# 52                        (-0.7, 0.2)    False
# 53             (0.0, 0.0666666666667)    False
# 54                         (0.0, 0.0)    False
# 55                       (0.0, 0.575)    False
# 56                         (0.0, 0.0)    False
# 57             (0.0, 0.0666666666667)    False
# 58                         (0.0, 0.0)    False
# 59              (0.0, 0.333333333333)    False
# 60            (-0.05, 0.191666666667)    False
# 61             (0.0, 0.0666666666667)    False
# 62            (-0.05, 0.191666666667)    False
# 63                         (0.0, 0.0)    False
# 64                         (0.0, 0.0)    False
# 65                         (0.0, 0.0)    False
# 66                        (-0.7, 0.2)    False
# 67                         (0.0, 0.4)    False
# 68           (-0.175, 0.783333333333)    False
# 69              (0.0, 0.333333333333)    False
# 70                         (0.0, 0.0)    False
# 71                        (-0.7, 0.2)    False
# 72                        (-0.7, 0.2)    False
# 73                         (0.0, 0.0)    False
# 74                  (-0.0625, 0.0625)    False
# 75                         (0.0, 0.0)    False
#
#                                           Assessments  \
# 0                                                  []
# 1                                                  []
# 2                   [([frustrated], -0.7, 0.2, None)]
# 3                                                  []
# 4                                                  []
# 5                        [([fourth], 0.0, 0.0, None)]
# 6                   [([frustrated], -0.7, 0.2, None)]
# 7                                                  []
# 8                                                  []
# 9              [([last], 0.0, 0.0666666666667, None)]
# 10                       [([fourth], 0.0, 0.0, None)]
# 11                                                 []
# 12                      [([crucial], 0.0, 1.0, None)]
# 13                                                 []
# 14                        [([daily], 0.0, 0.0, None)]
# 15                       [([fourth], 0.0, 0.0, None)]
# 16             [([last], 0.0, 0.0666666666667, None)]
# 17                        [([dead], -0.2, 0.4, None)]
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21  [([extremely, frustrated], -0.7, 0.2, None), (...
# 22                       [([fourth], 0.0, 0.0, None)]
# 23                                                 []
# 24                       [([total], 0.0, 0.75, None)]
# 25                                                 []
# 26                  [([frustrated], -0.7, 0.2, None)]
# 27                       [([fourth], 0.0, 0.0, None)]
# 28  [([largely, constant], 0.0, 0.333333333333, No...
# 29  [([right], 0.285714285714, 0.535714285714, Non...
# ..                                                ...
# 46  [([total], 0.0, 0.75, None), ([current], 0.0, ...
# 47  [([largely, constant], 0.0, 0.333333333333, No...
# 48                                                 []
# 49           [([active], -0.133333333333, 0.6, None)]
# 50                                                 []
# 51                       [([fourth], 0.0, 0.0, None)]
# 52                  [([frustrated], -0.7, 0.2, None)]
# 53             [([last], 0.0, 0.0666666666667, None)]
# 54                       [([fourth], 0.0, 0.0, None)]
# 55  [([total], 0.0, 0.75, None), ([current], 0.0, ...
# 56                                                 []
# 57             [([last], 0.0, 0.0666666666667, None)]
# 58                                                 []
# 59  [([largely, constant], 0.0, 0.333333333333, No...
# 60  [([frustrated], -0.7, 0.2, None), ([academic],...
# 61             [([last], 0.0, 0.0666666666667, None)]
# 62  [([frustrated], -0.7, 0.2, None), ([academic],...
# 63                       [([fourth], 0.0, 0.0, None)]
# 64                                                 []
# 65                                                 []
# 66                  [([frustrated], -0.7, 0.2, None)]
# 67                      [([current], 0.0, 0.4, None)]
# 68  [([angry], -0.5, 1.0, None), ([frustrated], -0...
# 69  [([largely, constant], 0.0, 0.333333333333, No...
# 70                                                 []
# 71                  [([frustrated], -0.7, 0.2, None)]
# 72                  [([frustrated], -0.7, 0.2, None)]
# 73                                                 []
# 74  [([russian], 0.0, 0.0, None), ([foreign], -0.1...
# 75                                                 []
#
#                       Source  Retweets  User Status  sentiment score
# 0                ri_covid_19         0          315         0.000000
# 1            Twitter Web App       102       348030         0.000000
# 2         Twitter for iPhone         0        43243        -0.700000
# 3        Twitter for Android         2       232906         0.000000
# 4        Twitter for Android        89         4344         0.000000
# 5            Twitter Web App        13         9743         0.000000
# 6        Twitter for Android        76        15515        -0.700000
# 7        Twitter for Android        98         3320         0.000000
# 8        Twitter for Android         0            8         0.000000
# 9           Twitter for iPad         0        30774         0.000000
# 10           Twitter Web App        13        34078         0.000000
# 11       Twitter for Android        24        73299         0.000000
# 12           Twitter Web App        50         3869         0.000000
# 13           Twitter Web App       102       348029         0.000000
# 14        Twitter for iPhone        11        10821         0.000000
# 15        Twitter for iPhone        13         6794         0.000000
# 16                 TweetDeck         1        15061         0.000000
# 17       Twitter for Android        45         1653        -0.200000
# 18                   dlvr.it         0        38697         0.000000
# 19           Twitter Web App         2        56200         0.000000
# 20       Twitter for Android         0        91780         0.000000
# 21        Twitter for iPhone         0         8295        -0.600000
# 22        Twitter for iPhone        13         5291         0.000000
# 23       Twitter for Android         0           56         0.000000
# 24           Twitter Web App        65        22973         0.000000
# 25     CoronavirusTrackerBot         0          199         0.000000
# 26        Twitter for iPhone         0        43243        -0.700000
# 27          Twitter for iPad        13        53283         0.000000
# 28        Twitter for iPhone        78         2753         0.000000
# 29       Twitter for Android         1        76085        -0.107143
# ..                       ...       ...          ...              ...
# 46  CoronaVirus Bot by Sloth         1        13003         0.000000
# 47        Twitter for iPhone        78         7848         0.000000
# 48        Twitter for iPhone         2        40796         0.000000
# 49        corona-tracker-app         0        13927        -0.133333
# 50       Twitter for Android        17        22229         0.000000
# 51       Twitter for Android        13        13587         0.000000
# 52        Twitter for iPhone         0        43243        -0.700000
# 53       Twitter for Android        95        29433         0.000000
# 54       Twitter for Android        13         5510         0.000000
# 55        Twitter for iPhone         1        23664         0.000000
# 56           Twitter Web App         0        10615         0.000000
# 57       Twitter for Android        95        15767         0.000000
# 58           Twitter Web App         3          106         0.000000
# 59       Twitter for Android        78        28727         0.000000
# 60           Twitter Web App         1       216948        -0.050000
# 61                  #COVID19         1        87230         0.000000
# 62        Twitter for iPhone         1        15866        -0.050000
# 63        Twitter for iPhone        13        77322         0.000000
# 64       Twitter for Android        25         9940         0.000000
# 65       Twitter for Android         0          143         0.000000
# 66           Twitter Web App        76          885        -0.700000
# 67           Twitter Web App         1       131706         0.000000
# 68             Sprout Social         0        11116        -0.175000
# 69        Twitter for iPhone        78       273632         0.000000
# 70                 TweetDeck         2        12360         0.000000
# 71        Twitter for iPhone        76        51779        -0.700000
# 72           Twitter Web App         0          103        -0.700000
# 73       Twitter for Android         0         3110         0.000000
# 74                 TweetDeck         1       164717        -0.062500
# 75           Twitter Web App         2        81124         0.000000
#
# [76 rows x 11 columns]

# %% [markdown]
# #### Positive Tweet

# %%
pandaPos = dfPosStop.toPandas()
sentimentScore = 0
countPos = 0
poslist = list()

for index, row in pandaPos.iterrows():
    if not positive(row["tweetnostopwords"]) and sentiment(row["tweetnostopwords"])[0] != 0.0:
        countPos = countPos + 1
    score = sentiment(row['tweetnostopwords'])[0]
    if score > 0:
        poslist.append((row['country'],row['city'], row['createdat'], row['hashtagkeys'], sentiment(row["tweetnostopwords"]), positive(row["tweetnostopwords"]), \
                         sentiment(row['tweetnostopwords']).assessments, row['source'], row['retweets'], row['userstatuscount'], score))
        sentimentScore = score + sentimentScore
    else:
        netralList.append((row['country'], row['city'], row['createdat'], row['hashtagkeys'], sentiment(row["tweetnostopwords"]), positive(row["tweetnostopwords"]), \
                           sentiment(row['tweetnostopwords']).assessments, row['source'], row['retweets'], row['userstatuscount'], score))
        
postiveTweetScores = pandas.DataFrame.from_records(poslist, columns=labels)
postiveTweetScores
# Out:
#         Country            City   Create_At  \
# 0       unknown         unknown  2021-05-07
# 1       unknown         unknown  2021-05-07
# 2       unknown           Dubai  2021-05-07
# 3        Canada         Toronto  2021-05-07
# 4       unknown         unknown  2021-05-07
# 5       unknown         Seattle  2021-05-07
# 6       unknown         unknown  2021-05-07
# 7       unknown         unknown  2021-05-07
# 8         India       Hyderabad  2021-05-07
# 9       unknown         unknown  2021-05-07
# 10      unknown       Amsterdam  2021-05-07
# 11      unknown         unknown  2021-05-07
# 12      unknown         unknown  2021-05-07
# 13      unknown      Charleston  2021-05-07
# 14        India            Kota  2021-05-07
# 15      unknown  San Bernardino  2021-05-07
# 16  Switzerland          Geneva  2021-05-07
# 17      unknown           Rabat  2021-05-07
# 18  South Korea         unknown  2021-05-07
# 19      unknown         unknown  2021-05-07
# 20      unknown         unknown  2021-05-07
# 21      unknown         unknown  2021-05-07
# 22        Japan           Tokyo  2021-05-07
# 23      unknown             Bar  2021-05-07
# 24      unknown         unknown  2021-05-07
# 25      unknown        Sarasota  2021-05-07
# 26      unknown       San Diego  2021-05-07
# 27      unknown         unknown  2021-05-07
# 28      unknown         unknown  2021-05-07
# 29      unknown         unknown  2021-05-07
# ..          ...             ...         ...
# 57      unknown          Athens  2021-05-07
# 58    Australia       Melbourne  2021-05-07
# 59  New Zealand         unknown  2021-05-07
# 60      unknown            Kent  2021-05-07
# 61      unknown         unknown  2021-05-07
# 62      unknown         Calgary  2021-05-07
# 63  New Zealand         unknown  2021-05-07
# 64      unknown         unknown  2021-05-07
# 65      unknown  San Bernardino  2021-05-07
# 66      unknown         unknown  2021-05-07
# 67      unknown         unknown  2021-05-07
# 68        India         unknown  2021-05-07
# 69      unknown        Portland  2021-05-07
# 70      unknown         unknown  2021-05-07
# 71      unknown         Toronto  2021-05-07
# 72      unknown         unknown  2021-05-07
# 73       Canada         Toronto  2021-05-07
# 74      unknown         unknown  2021-05-07
# 75      unknown         unknown  2021-05-07
# 76      Ireland         unknown  2021-05-07
# 77      unknown         unknown  2021-05-07
# 78      unknown             Bar  2021-05-07
# 79      unknown         unknown  2021-05-07
# 80      unknown         unknown  2021-05-07
# 81      unknown   San Francisco  2021-05-07
# 82      unknown         unknown  2021-05-07
# 83      unknown   San Francisco  2021-05-07
# 84        India         unknown  2021-05-07
# 85      unknown       San Diego  2021-05-07
# 86      unknown        Istanbul  2021-05-07
#
#                         Hashtags Keyword                     Sentiment Score  \
# 0                                Binance    (0.116666666667, 0.133333333333)
# 1                      covid19,economics                          (0.1, 0.6)
# 2                                COVID19    (0.103703703704, 0.477777777778)
# 3                        Toronto,COVID19               (0.136363636364, 0.5)
# 4                                COVID19              (0.25, 0.333333333333)
# 5                           HugAHesitant                          (0.6, 0.9)
# 6                                unknown    (0.166666666667, 0.333333333333)
# 7                                COVID19    (0.518181818182, 0.677272727273)
# 8                                COVID19                        (0.35, 0.65)
# 9                                unknown    (0.318181818182, 0.527272727273)
# 10                     covid19,economics                          (0.1, 0.6)
# 11                               unknown                       (0.625, 0.95)
# 12                               unknown              (0.35, 0.333333333333)
# 13                               unknown   (0.0333333333333, 0.233333333333)
# 14                               Covid19    (0.227272727273, 0.545454545455)
# 15                               COVID19                         (0.3, 0.45)
# 16                     covid19,economics                          (0.1, 0.6)
# 17                               unknown                          (0.5, 1.0)
# 18                               COVID19   (0.0327380952381, 0.556547619048)
# 19                               Covid19    (0.227272727273, 0.545454545455)
# 20                               COVID19   (0.0327380952381, 0.556547619048)
# 21                     covid19,economics                          (0.1, 0.6)
# 22                               Binance    (0.116666666667, 0.133333333333)
# 23                               COVID19    (0.136363636364, 0.454545454545)
# 24                     covid19,economics                          (0.1, 0.6)
# 25                               unknown                          (0.3, 0.4)
# 26                               COVID19               (0.136363636364, 0.5)
# 27                     covid19,economics                          (0.1, 0.6)
# 28                               unknown    (0.166666666667, 0.333333333333)
# 29                         StandTogether                          (0.4, 0.4)
# ..                                   ...                                 ...
# 57                     covid19,economics                          (0.1, 0.6)
# 58                               unknown    (0.166666666667, 0.333333333333)
# 59                               unknown    (0.166666666667, 0.333333333333)
# 60                               COVID19    (0.518181818182, 0.677272727273)
# 61                               COVID19                          (0.1, 0.2)
# 62                     ZeroCOVID,COVID19    (0.212121212121, 0.218181818182)
# 63                               unknown    (0.166666666667, 0.333333333333)
# 64                               COVID19              (0.25, 0.333333333333)
# 65                               COVID19                         (0.3, 0.45)
# 66                     covid19,economics                          (0.1, 0.6)
# 67                               COVID19    (0.111111111111, 0.222222222222)
# 68                               Covid19    (0.227272727273, 0.545454545455)
# 69                               unknown    (0.166666666667, 0.355555555556)
# 70  KBhagyaraj,PoornimaBhagyaraj,Covid19    (0.227272727273, 0.545454545455)
# 71                       Toronto,COVID19               (0.136363636364, 0.5)
# 72                               COVID19             (0.175, 0.308333333333)
# 73                       Toronto,COVID19               (0.136363636364, 0.5)
# 74                               unknown              (0.25, 0.333333333333)
# 75                               COVID19  (0.0333333333333, 0.0666666666667)
# 76                               COVID19                          (0.1, 0.1)
# 77                               COVID19    (0.518181818182, 0.677272727273)
# 78                               COVID19    (0.136363636364, 0.454545454545)
# 79                               COVID19             (0.175, 0.308333333333)
# 80                               COVID19                          (1.0, 1.0)
# 81                               COVID19             (0.175, 0.308333333333)
# 82                     covid19,economics                          (0.1, 0.6)
# 83                               COVID19                        (0.35, 0.55)
# 84                               Covid19    (0.227272727273, 0.545454545455)
# 85                               COVID19   (0.0327380952381, 0.556547619048)
# 86                     covid19,economics                          (0.1, 0.6)
#
#     Postive                                        Assessments  \
# 0      True  [([social], 0.0333333333333, 0.0666666666667, ...
# 1      True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 2      True  [([tough], -0.388888888889, 0.833333333333, No...
# 3      True              [([live], 0.136363636364, 0.5, None)]
# 4      True            [([first], 0.25, 0.333333333333, None)]
# 5      True                      [([amazing], 0.6, 0.9, None)]
# 6      True  [([older], 0.166666666667, 0.333333333333, None)]
# 7      True  [([incredibly], 0.9, 0.9, None), ([new], 0.136...
# 8      True  [([beloved], 0.7, 1.0, None), ([personally], 0...
# 9      True  [([love], 0.5, 0.6, None), ([new], 0.136363636...
# 10     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 11     True  [([welcome], 0.8, 0.9, None), ([fabulous], 0.4...
# 12     True  [([good], 0.7, 0.6, None), ([public], 0.0, 0.0...
# 13    False  [([old], 0.1, 0.2, None), ([enough], 0.0, 0.5,...
# 14     True  [([positive], 0.227272727273, 0.545454545455, ...
# 15     True  [([free], 0.4, 0.8, None), ([wants], 0.2, 0.1,...
# 16     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 17     True                   [([innovative], 0.5, 1.0, None)]
# 18    False  [([special], 0.357142857143, 0.571428571429, N...
# 19     True  [([positive], 0.227272727273, 0.545454545455, ...
# 20    False  [([special], 0.357142857143, 0.571428571429, N...
# 21     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 22     True  [([social], 0.0333333333333, 0.0666666666667, ...
# 23     True    [([new], 0.136363636364, 0.454545454545, None)]
# 24     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 25     True                 [([intellectual], 0.3, 0.4, None)]
# 26     True              [([live], 0.136363636364, 0.5, None)]
# 27     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 28     True  [([older], 0.166666666667, 0.333333333333, None)]
# 29     True                    [([available], 0.4, 0.4, None)]
# ..      ...                                                ...
# 57     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 58     True  [([older], 0.166666666667, 0.333333333333, None)]
# 59     True  [([older], 0.166666666667, 0.333333333333, None)]
# 60     True  [([incredibly], 0.9, 0.9, None), ([new], 0.136...
# 61     True                          [([old], 0.1, 0.2, None)]
# 62     True  [([new], 0.136363636364, 0.454545454545, None)...
# 63     True  [([older], 0.166666666667, 0.333333333333, None)]
# 64     True            [([first], 0.25, 0.333333333333, None)]
# 65     True  [([free], 0.4, 0.8, None), ([wants], 0.2, 0.1,...
# 66     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 67     True  [([social], 0.0333333333333, 0.0666666666667, ...
# 68     True  [([positive], 0.227272727273, 0.545454545455, ...
# 69     True  [([last], 0.0, 0.0666666666667, None), ([many]...
# 70     True  [([positive], 0.227272727273, 0.545454545455, ...
# 71     True              [([live], 0.136363636364, 0.5, None)]
# 72     True  [([full], 0.35, 0.55, None), ([last], 0.0, 0.0...
# 73     True              [([live], 0.136363636364, 0.5, None)]
# 74     True            [([first], 0.25, 0.333333333333, None)]
# 75    False  [([social], 0.0333333333333, 0.0666666666667, ...
# 76     True  [([spanish], 0.0, 0.0, None), ([economic], 0.2...
# 77     True  [([incredibly], 0.9, 0.9, None), ([new], 0.136...
# 78     True    [([new], 0.136363636364, 0.454545454545, None)]
# 79     True  [([full], 0.35, 0.55, None), ([last], 0.0, 0.0...
# 80     True                    [([wonderful], 1.0, 1.0, None)]
# 81     True  [([full], 0.35, 0.55, None), ([last], 0.0, 0.0...
# 82     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
# 83     True                       [([full], 0.35, 0.55, None)]
# 84     True  [([positive], 0.227272727273, 0.545454545455, ...
# 85    False  [([special], 0.357142857143, 0.571428571429, N...
# 86     True  [([key], 0.0, 1.0, None), ([economic], 0.2, 0....
#
#                  Source  Retweets  User Status  sentiment score
# 0    Twitter for iPhone         4          617         0.116667
# 1      Twitter for iPad        12        15526         0.100000
# 2    Twitter for iPhone       151         2770         0.103704
# 3   Twitter for Android         7         2182         0.136364
# 4       Twitter Web App         1         1857         0.250000
# 5       Twitter Web App         0         4085         0.600000
# 6   Twitter for Android         1        13377         0.166667
# 7    Twitter for iPhone        35       128843         0.518182
# 8   Twitter for Android        79           91         0.350000
# 9   Twitter for Android        14          576         0.318182
# 10                IFTTT         0        37144         0.100000
# 11  Twitter for Android       100       163559         0.625000
# 12      Twitter Web App         0        47772         0.350000
# 13  Twitter for Android        13         1715         0.033333
# 14  Twitter for Android       162        27055         0.227273
# 15      Twitter Web App      1132         2303         0.300000
# 16               Buffer        12       164654         0.100000
# 17  Twitter for Android         2          154         0.500000
# 18  Twitter for Android        95         1125         0.032738
# 19   Twitter for iPhone       162          452         0.227273
# 20  Twitter for Android        95        19383         0.032738
# 21   Twitter for iPhone        12       226338         0.100000
# 22   Twitter for iPhone         4         8601         0.116667
# 23      Twitter Web App       852         4079         0.136364
# 24   Twitter for iPhone        12         2130         0.100000
# 25        Sprout Social         0         6894         0.300000
# 26      Twitter Web App        23          906         0.136364
# 27   Twitter for iPhone        12           24         0.100000
# 28  Twitter for Android         2        13377         0.166667
# 29  Twitter for Android     13228         3648         0.400000
# ..                  ...       ...          ...              ...
# 57   Twitter for iPhone        12         4731         0.100000
# 58  Twitter for Android         2         1722         0.166667
# 59      Twitter Web App         1         7636         0.166667
# 60   Twitter for iPhone        35        21162         0.518182
# 61      Twitter Web App        56        20282         0.100000
# 62      Twitter Web App         0        89935         0.212121
# 63      Twitter Web App         2         7636         0.166667
# 64   Twitter for iPhone         1        13793         0.250000
# 65      Twitter Web App      1132         2304         0.300000
# 66  Twitter for Android        12         7878         0.100000
# 67        Sprout Social         1        10264         0.111111
# 68  Twitter for Android       162         5543         0.227273
# 69      Twitter Web App         0        24945         0.166667
# 70  Twitter for Android       865        76389         0.227273
# 71  Twitter for Android         7        15063         0.136364
# 72       SocialNewsDesk         4         9307         0.175000
# 73   Twitter for iPhone         7       114614         0.136364
# 74   Twitter for iPhone         0         1637         0.250000
# 75      Twitter Web App         9       621164         0.033333
# 76  Twitter for Android        23         2167         0.100000
# 77   Twitter for iPhone        35       694605         0.518182
# 78      Twitter Web App       852         4080         0.136364
# 79       SocialNewsDesk         4         7848         0.175000
# 80   Twitter for iPhone         2        11332         1.000000
# 81       SocialNewsDesk         4        12758         0.175000
# 82   Twitter for iPhone        12        11240         0.100000
# 83      Twitter Web App         4       175793         0.350000
# 84  Twitter for Android       162          563         0.227273
# 85      Twitter Web App        95          906         0.032738
# 86   Twitter for iPhone        12         5422         0.100000
#
# [87 rows x 11 columns]

# %% [markdown]
# #### Neutral Tweets and concatenating and saving all 3 dataframes into one csv

# %%
neutralTweetScores = pandas.DataFrame.from_records(nutralList, columns=labels)
neutralTweetScores
# Out:
#           Country              City   Create_At             Hashtags Keyword  \
# 0          Canada           Toronto  2021-05-07                      unknown
# 1         unknown           unknown  2021-05-07                      COVID19
# 2         unknown           unknown  2021-05-07                      unknown
# 3         unknown           unknown  2021-05-07                      unknown
# 4         unknown             Leeds  2021-05-07                      COVID19
# 5         unknown           unknown  2021-05-07                      COVID19
# 6         unknown           unknown  2021-05-07                      COVID19
# 7         unknown  Garfield Heights  2021-05-07                      COVID19
# 8          France             Paris  2021-05-07                      COVID19
# 9         unknown             Texas  2021-05-06                      COVID19
# 10        unknown           unknown  2021-05-06                      COVID19
# 11        unknown           unknown  2021-05-06                      COVID19
# 12      Australia           unknown  2021-05-07                      COVID19
# 13        unknown           unknown  2021-05-06                      COVID19
# 14   South Africa           unknown  2021-05-07                      COVID19
# 15        unknown           unknown  2021-05-07                      COVID19
# 16        unknown            Austin  2021-05-06                      COVID19
# 17        unknown             Tampa  2021-05-07                      COVID19
# 18        unknown              Iowa  2021-05-06                      COVID19
# 19        unknown       Schenectady  2021-05-06                      COVID19
# 20        unknown           unknown  2021-05-07                      COVID19
# 21        unknown           unknown  2021-05-07                      COVID19
# 22        unknown           unknown  2021-05-07                India,COVID19
# 23        unknown            Boston  2021-05-07                      COVID19
# 24        unknown             Texas  2021-05-06                      COVID19
# 25        unknown           unknown  2021-05-06                      COVID19
# 26        unknown           unknown  2021-05-07  COVID19,StaySafeStayHealthy
# 27        Georgia           unknown  2021-05-07                      COVID19
# 28        unknown           unknown  2021-05-06                      COVID19
# 29        unknown           unknown  2021-05-06                      COVID19
# ..            ...               ...         ...                          ...
# 103       unknown           unknown  2021-05-06                      COVID19
# 104       Nigeria             Daura  2021-05-07                      COVID19
# 105       unknown           unknown  2021-05-06                      COVID19
# 106       unknown           unknown  2021-05-07                      COVID19
# 107       unknown           unknown  2021-05-06                      COVID19
# 108       unknown           unknown  2021-05-06                      COVID19
# 109       unknown           Madison  2021-05-07                      COVID19
# 110       unknown           unknown  2021-05-07                      unknown
# 111       unknown           unknown  2021-05-07                      COVID19
# 112       unknown          Columbia  2021-05-07                      unknown
# 113       unknown           unknown  2021-05-06                      COVID19
# 114       unknown           Medford  2021-05-06                      COVID19
# 115       unknown           unknown  2021-05-07                      COVID19
# 116       unknown           unknown  2021-05-06                      COVID19
# 117       unknown           unknown  2021-05-06                      COVID19
# 118       unknown           unknown  2021-05-07                      COVID19
# 119       unknown           Torreon  2021-05-07                      COVID19
# 120       unknown           unknown  2021-05-06                      COVID19
# 121       unknown           unknown  2021-05-06                      COVID19
# 122       unknown           unknown  2021-05-07                      COVID19
# 123       unknown           unknown  2021-05-07                      COVID19
# 124       unknown           unknown  2021-05-06                      COVID19
# 125       unknown           unknown  2021-05-06                      COVID19
# 126       unknown           unknown  2021-05-06                      COVID19
# 127       unknown           Raleigh  2021-05-06                      COVID19
# 128       unknown           unknown  2021-05-06                      COVID19
# 129       unknown         Milwaukee  2021-05-06                      COVID19
# 130       unknown           unknown  2021-05-07                      COVID19
# 131       unknown           unknown  2021-05-06                      COVID19
# 132       unknown         Vancouver  2021-05-07                      COVID19
#
#                       Sentiment Score  Postive  \
# 0    (0.166666666667, 0.533333333333)     True
# 1    (0.466666666667, 0.716666666667)     True
# 2                          (0.3, 0.2)     True
# 3             (0.0833333333333, 0.55)    False
# 4               (0.333333333333, 0.5)     True
# 5                        (0.325, 0.7)     True
# 6                        (0.325, 0.7)     True
# 7    (0.466666666667, 0.716666666667)     True
# 8                        (0.325, 0.7)     True
# 9    (0.466666666667, 0.716666666667)     True
# 10   (0.466666666667, 0.716666666667)     True
# 11   (0.466666666667, 0.716666666667)     True
# 12   (0.466666666667, 0.716666666667)     True
# 13   (0.466666666667, 0.716666666667)     True
# 14   (0.133333333333, 0.833333333333)     True
# 15                       (0.325, 0.7)     True
# 16   (0.466666666667, 0.716666666667)     True
# 17                       (0.25, 0.65)     True
# 18   (0.466666666667, 0.716666666667)     True
# 19   (0.466666666667, 0.716666666667)     True
# 20                       (0.325, 0.7)     True
# 21   (0.212121212121, 0.584848484848)     True
# 22   (0.136363636364, 0.454545454545)     True
# 23                         (0.4, 1.0)     True
# 24   (0.466666666667, 0.716666666667)     True
# 25   (0.466666666667, 0.716666666667)     True
# 26              (0.181818181818, 0.5)     True
# 27   (0.466666666667, 0.716666666667)     True
# 28   (0.466666666667, 0.716666666667)     True
# 29   (0.466666666667, 0.716666666667)     True
# ..                                ...      ...
# 103  (0.466666666667, 0.716666666667)     True
# 104  (0.136363636364, 0.454545454545)     True
# 105  (0.466666666667, 0.716666666667)     True
# 106  (0.466666666667, 0.716666666667)     True
# 107  (0.466666666667, 0.716666666667)     True
# 108  (0.466666666667, 0.716666666667)     True
# 109                      (0.325, 0.7)     True
# 110           (0.125, 0.166666666667)     True
# 111                      (0.325, 0.7)     True
# 112  (0.268181818182, 0.727272727273)     True
# 113  (0.466666666667, 0.716666666667)     True
# 114  (0.466666666667, 0.716666666667)     True
# 115                      (0.325, 0.7)     True
# 116  (0.466666666667, 0.716666666667)     True
# 117  (0.466666666667, 0.716666666667)     True
# 118                      (0.325, 0.7)     True
# 119                      (0.325, 0.7)     True
# 120  (0.466666666667, 0.716666666667)     True
# 121  (0.466666666667, 0.716666666667)     True
# 122                      (0.325, 0.7)     True
# 123  (0.466666666667, 0.716666666667)     True
# 124  (0.466666666667, 0.716666666667)     True
# 125  (0.466666666667, 0.716666666667)     True
# 126  (0.466666666667, 0.716666666667)     True
# 127  (0.466666666667, 0.716666666667)     True
# 128  (0.466666666667, 0.716666666667)     True
# 129  (0.466666666667, 0.716666666667)     True
# 130  (0.466666666667, 0.716666666667)     True
# 131  (0.466666666667, 0.716666666667)     True
# 132  (0.466666666667, 0.716666666667)     True
#
#                                            Assessments               Source  \
# 0    [([fair], 0.7, 0.9, None), ([anger], -0.7, 0.2...  Twitter for Android
# 1    [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 2                            [([fun], 0.3, 0.2, None)]  Twitter for Android
# 3    [([fresh], 0.3, 0.5, None), ([active], -0.1333...  Twitter for Android
# 4            [([pregnant], 0.333333333333, 0.5, None)]  Twitter for Android
# 5    [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....  Twitter for Android
# 6    [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....      Twitter Web App
# 7    [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 8    [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....  Twitter for Android
# 9    [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 10   [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 11   [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 12   [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 13   [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 14   [([total], 0.0, 0.75, None), ([confirmed], 0.4...  Twitter for Android
# 15   [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....      Twitter Web App
# 16   [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 17   [([latest], 0.5, 0.9, None), ([related], 0.0, ...   Twitter for iPhone
# 18   [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 19   [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 20   [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....      Twitter Web App
# 21   [([latest], 0.5, 0.9, None), ([new], 0.1363636...      Twitter Web App
# 22     [([new], 0.136363636364, 0.454545454545, None)]      Twitter Web App
# 23                     [([confirmed], 0.4, 1.0, None)]  Twitter for Android
# 24   [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 25   [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 26   [([new], 0.136363636364, 0.454545454545, None)...   Twitter for iPhone
# 27   [([easily], 0.433333333333, 0.833333333333, No...     Twitter for iPad
# 28   [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 29   [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# ..                                                 ...                  ...
# 103  [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 104    [([new], 0.136363636364, 0.454545454545, None)]  Twitter for Android
# 105  [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 106  [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 107  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 108  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 109  [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....  Twitter for Android
# 110  [([20th], 0.0, 0.0, None), ([first], 0.25, 0.3...      Twitter Web App
# 111  [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....  Twitter for Android
# 112  [([new], 0.136363636364, 0.454545454545, None)...   Twitter for iPhone
# 113  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 114  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 115  [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....  Twitter for Android
# 116  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 117  [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 118  [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....      Twitter Web App
# 119  [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....   Twitter for iPhone
# 120  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 121  [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 122  [([huge], 0.4, 0.9, None), ([higher], 0.25, 0....  Twitter for Android
# 123  [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 124  [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 125  [([easily], 0.433333333333, 0.833333333333, No...   Twitter for iPhone
# 126  [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 127  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 128  [([easily], 0.433333333333, 0.833333333333, No...  Twitter for Android
# 129  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 130  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 131  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
# 132  [([easily], 0.433333333333, 0.833333333333, No...      Twitter Web App
#
#      Retweets  User Status  sentiment score
# 0           0         1540         0.166667
# 1         398        64373         0.466667
# 2           2           74         0.300000
# 3          18       242872         0.083333
# 4         291          215         0.333333
# 5        1394        56104         0.325000
# 6        1394        23493         0.325000
# 7         398        81643         0.466667
# 8        1394        16584         0.325000
# 9         398       138651         0.466667
# 10        398         3666         0.466667
# 11        398        38742         0.466667
# 12        398         2742         0.466667
# 13        398       111669         0.466667
# 14          6        11244         0.133333
# 15       1394        12516         0.325000
# 16        398       118750         0.466667
# 17          1         2788         0.250000
# 18        398        44266         0.466667
# 19        398        14825         0.466667
# 20       1394         1364         0.325000
# 21          1       122635         0.212121
# 22          0         9677         0.136364
# 23          2        29577         0.400000
# 24        398        60313         0.466667
# 25        398       206714         0.466667
# 26        579        56719         0.181818
# 27        398       101450         0.466667
# 28        398       130292         0.466667
# 29        398        54915         0.466667
# ..        ...          ...              ...
# 103       398         7574         0.466667
# 104         2        75511         0.136364
# 105       398        44674         0.466667
# 106       398          271         0.466667
# 107       398        11656         0.466667
# 108       398       153963         0.466667
# 109      1394       112871         0.325000
# 110         0        52089         0.125000
# 111      1394        18887         0.325000
# 112        10         3771         0.268182
# 113       398         6283         0.466667
# 114       398          529         0.466667
# 115      1394        23096         0.325000
# 116       398        69057         0.466667
# 117       398        12476         0.466667
# 118      1394         6866         0.325000
# 119      1394         2219         0.325000
# 120       398         1684         0.466667
# 121       398         8829         0.466667
# 122      1394        17292         0.325000
# 123       398           50         0.466667
# 124       398        10459         0.466667
# 125       398         3104         0.466667
# 126       398        13077         0.466667
# 127       398        96931         0.466667
# 128       398        39369         0.466667
# 129       398         4883         0.466667
# 130       398        18416         0.466667
# 131       398       119731         0.466667
# 132       398       449728         0.466667
#
# [133 rows x 11 columns]

# %%
df = pandas.concat([negativeTweetScores, postiveTweetScores, neutralTweetScores])
csv_name = '/project_folder/allTweetSentimentsfinal.csv'
df.to_csv(csv_name, index = False, header=True, encoding='utf-8-sig')

# %%
df = pandas.read_csv(csv_name)
final_dict = {}
for i, group in df.groupby(['Country']):
    # print(group)
    # break
    p_grp = group[group['Postive'].apply(lambda x: x == True)]
    n_grp = group[group['Postive'].apply(lambda x: x == False)]

    if i not in final_dict:
        final_dict[i] = {}
    pos = len(p_grp)
    neg = len(n_grp)
    pos_key = 'positive_count'
    if pos_key not in final_dict[i]:
        final_dict[i][pos_key] = pos
    neg_key = 'negative_count'
    if neg_key not in final_dict[i]:
        final_dict[i][neg_key] = neg

    sources = list(set(group.Source))
    num_sources = len(sources)
    s_key = 'sources'
    n_s_key = 'num_sources'
    if s_key not in final_dict[i]:
        final_dict[i][s_key] = sources
    if n_s_key not in final_dict[i]:
        final_dict[i][n_s_key] = num_sources

    p_hashtags = list(set(group['Hashtags Keyword']))
    p_all_hashtags = []
    for hashtag in p_hashtags:
        for x in hashtag.split(','):
            if x.strip() != 'unknown':
                p_all_hashtags.append(x.strip())
    p_hashtag_key = 'hashtags'
    if p_hashtag_key not in final_dict[i]:
        final_dict[i][p_hashtag_key] = list(set(p_all_hashtags))
    n_p_hashtag_key = 'num_hashtags'
    if n_p_hashtag_key not in final_dict[i]:
        final_dict[i][n_p_hashtag_key] = len(set(p_all_hashtags))

    clean_words = group.Assessments.apply(
        lambda x: re.findall(r"\[([A-Za-z0-9_]+)\]", x))
    all_clean_words = [y for x in clean_words for y in x]
    # all_clean_words = []
    # for x in clean_words:
    #     for y in x:
    #         all_clean_words.append(y)
    # print(all_clean_words)

    s_a_key = 'sentiment_assessment_words'
    if s_a_key not in final_dict[i]:
        final_dict[i][s_a_key] = all_clean_words

# %%
pandas.DataFrame.from_dict(final_dict).T
# Out:
#                                                          hashtags  \
# Argentina                                    [economics, covid19]
# Australia                                               [COVID19]
# Canada                                [Toronto, Ontario, COVID19]
# France                          [COVID19, Massachusetts, Covid19]
# Georgia                                                 [COVID19]
# Germany                                             [USA, Corona]
# Greece                                      [coronavirus, Greece]
# India                                          [COVID19, Covid19]
# Ireland                                                 [COVID19]
# Japan                                   [Binance, COVID19, JAPAN]
# Nepal                                                          []
# New Zealand                                                    []
# Nigeria                                                 [COVID19]
# Peru                                 [IndiaFightsCorona, COVID19]
# South Africa                                            [COVID19]
# South Korea                                             [COVID19]
# Sri Lanka                                                      []
# Switzerland                                  [economics, covid19]
# United Kingdom                                                 []
# United States                                           [COVID19]
# unknown         [Polio, Lockdown, tunisie, COVID19, Alberta, s...
#
#                negative_count num_hashtags num_sources positive_count  \
# Argentina                   0            2           1              1
# Australia                   0            1           2              2
# Canada                      2            3           3              3
# France                      1            3           2              1
# Georgia                     0            1           1              2
# Germany                     1            2           1              0
# Greece                      0            2           1              1
# India                       3            2           2              4
# Ireland                     0            1           3              3
# Japan                       0            3           2              2
# Nepal                       1            0           1              0
# New Zealand                 0            0           1              2
# Nigeria                     0            1           1              2
# Peru                        1            2           1              0
# South Africa                0            1           1              2
# South Korea                 1            1           1              0
# Sri Lanka                   1            0           1              0
# Switzerland                 0            2           1              1
# United Kingdom              1            0           1              0
# United States               0            1           2              2
# unknown                    77           33          19            179
#
#                                        sentiment_assessment_words  \
# Argentina                                         [key, economic]
# Australia                                   [older, easily, love]
# Canada                            [live, live, fair, anger, many]
# France                                       [last, huge, higher]
# Georgia                              [easily, love, easily, love]
# Germany                                                  [active]
# Greece                                           [new, confirmed]
# India           [beloved, personally, positive, positive, posi...
# Ireland            [incredibly, new, spanish, economic, new, old]
# Japan                                    [social, economic, many]
# Nepal                                                     [angry]
# New Zealand                                        [older, older]
# Nigeria                                                [new, new]
# Peru                                                           []
# South Africa    [total, confirmed, total, total, confirmed, to...
# South Korea                                       [special, hard]
# Sri Lanka                                         [young, social]
# Switzerland                                       [key, economic]
# United Kingdom                                             [last]
# United States                        [easily, love, easily, love]
# unknown         [frustrated, fourth, frustrated, fourth, cruci...
#
#                                                           sources
# Argentina                                       [Twitter Web App]
# Australia               [Twitter for iPhone, Twitter for Android]
# Canada          [Twitter for iPhone, Twitter Web App, Twitter ...
# France                            [#COVID19, Twitter for Android]
# Georgia                                        [Twitter for iPad]
# Germany                                      [corona-tracker-app]
# Greece                                      [Twitter for Android]
# India                       [SocialPilot.co, Twitter for Android]
# Ireland         [Twitter for iPad, Twitter Web App, Twitter fo...
# Japan                             [Twitter for iPhone, TweetDeck]
# Nepal                                        [Twitter for iPhone]
# New Zealand                                     [Twitter Web App]
# Nigeria                                     [Twitter for Android]
# Peru                                        [Twitter for Android]
# South Africa                                [Twitter for Android]
# South Korea                                 [Twitter for Android]
# Sri Lanka                                        [SocialPilot.co]
# Switzerland                                              [Buffer]
# United Kingdom                                 [Twitter for iPad]
# United States           [Twitter for iPhone, Twitter for Android]
# unknown         [Naattuvartha, Twitter for iPad, ContentStudio...
